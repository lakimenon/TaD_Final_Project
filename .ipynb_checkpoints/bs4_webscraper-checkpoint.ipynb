# %%
import pandas as pd

# %%
import bs4
import requests

# %%
! pip install wget

# %%
! wget https://www.rev.com/blog/transcript-tag/coronavirus-update-transcripts
# Out:
# --2020-04-23 18:08:51--  https://www.rev.com/blog/transcript-tag/coronavirus-update-transcripts
# Resolving www.rev.com (www.rev.com)... 52.33.243.140, 34.223.136.215, 34.208.249.145
# Connecting to www.rev.com (www.rev.com)|52.33.243.140|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘coronavirus-update-transcripts’
#
# coronavirus-update-     [ <=>                ]  84.98K  --.-KB/s    in 0.1s
#
# 2020-04-23 18:08:52 (831 KB/s) - ‘coronavirus-update-transcripts’ saved [87016]

# %%
soup = run_bs4('https://www.rev.com/blog/transcript-tag/coronavirus-update-transcripts')

# %%
for i in range(1,44): 
    soup = run_bs4(str('https://www.rev.com/blog/transcript-tag/coronavirus-update-transcripts/pages/' + str(i)))

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <title>Page not found - Rev</title>
# <!-- This site is optimized with the Yoast SEO Premium plugin v13.5 - https://yoast.com/wordpress/plugins/seo/ -->
# <meta content="noindex,follow" name="robots"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="object" property="og:type"/>
# <meta content="Page not found - Rev" property="og:title"/>
# <meta content="Rev" property="og:site_name"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="Page not found - Rev" name="twitter:title"/>
# <meta content="@rev" name="twitter:site"/>
# ...

# %%
for x in soup.find_all('a'):
    print(x.get('href'))
# Out:
# #fl-main-content
# /
# /about
# /careers
# /press
# /freelancers
# /blog/
# /transcription
# /caption
# /subtitle
# /translation
# /freelancers?fromMobileSideMenu=true
# /about
# /contact
# /account/auth/login
# /transcription
# /transcription/how-it-works
# /transcription/faq
# /voicerecorder
# /caption
# /caption/how-it-works
# /caption/faq
# /captionconverter
# /subtitle
# /translation
# /translation/certified
# /translation/business
# /translation/faq
# /order/quote
# /about
# /press
# /careers
# /freelancers
# /blog
# /api
# tel:888-369-0701
# mailto:support@rev.com
# https://twitter.com/rev
# https://www.facebook.com/rev
# https://www.linkedin.com/company/rev-com
# https://goo.gl/maps/GNikTTrd5aN2
# /reviews
# /about/terms
# /about/privacy
# https://www.rev.com/services?coupon=e4e6ff30
# https://www.rev.com/caption
# https://www.rev.com/caption
# https://www.rev.com/subtitle/translator
# https://www.rev.com/translation
# https://www.rev.com/transcription

# %%
! wget https://www.rev.com/blog/transcripts/donald-trump-coronavirus-press-conference-transcript-april-21
# Out:
# --2020-04-23 18:10:36--  https://www.rev.com/blog/transcripts/donald-trump-coronavirus-press-conference-transcript-april-21
# Resolving www.rev.com (www.rev.com)... 34.208.249.145, 34.223.136.215, 52.33.243.140
# Connecting to www.rev.com (www.rev.com)|34.208.249.145|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘donald-trump-coronavirus-press-conference-transcript-april-21’
#
# donald-trump-corona     [  <=>               ] 176.82K   591KB/s    in 0.3s
#
# 2020-04-23 18:10:37 (591 KB/s) - ‘donald-trump-coronavirus-press-conference-transcript-april-21’ saved [181061]

# %%
with open('donald-trump-coronavirus-press-conference-transcript-april-21', 'r') as file:
    print(file.readlines())
# Out:
# ['<!DOCTYPE html><html lang="en-US"><head><meta charset="UTF-8" /><meta name=\'viewport\' content=\'width=device-width, initial-scale=1.0\' /><meta http-equiv=\'X-UA-Compatible\' content=\'IE=edge\' /><link rel="profile" href="https://gmpg.org/xfn/11" /><title>Donald Trump Coronavirus Press Conference Transcript April 21 - Rev</title><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Noto%20Serif%3A400%2C400i%2C700%2C700i%7CRubik%3A300%2C400%2C700%2C400%7CRubik%3A300%2C400%2C500&#038;display=swap" /><link rel="stylesheet" href="https://www.rev.com/blog/wp-content/cache/min/1/e1c6881cc81f7a2a3f5707bb543ada84.css" data-minify="1" /><meta name="description" content="President Donald Trump&#039;s April 21 coronavirus task force press conference. He outlined his plans to slow immigration, including halting most green cards for 60 days. Read the full transcript here."/><meta name="robots" content="max-snippet:-1, max-image-preview:large, max-video-preview:-1"/><link rel="
# ...

# %%
def run_bs4(link, lxml=None):
    user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.122 Safari/537.36'
    headers = {'User-Agent': user_agent}
    page = requests.get(link)
    html = page.content
    soup = bs4.BeautifulSoup(html, 'html.parser')
    return(soup)

# %%
bs4.BeautifulSoup('donald-trump-coronavirus-press-conference-transcript-april-21')
# Out:
# /Users/angelateng/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:294: UserWarning: "b'donald-trump-coronavirus-press-conference-transcript-april-21'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# <html><body><p>donald-trump-coronavirus-press-conference-transcript-april-21</p></body></html>

# %%
soup = run_bs4('https://www.rev.com/blog/transcripts/donald-trump-coronavirus-press-conference-transcript-april-21')

# %%
for x in soup.find_all('p'):
    print(x.find_all(text=True))
# Out:
# ['Apr 21, 2020']
# ['President Donald Trump’s April 21 coronavirus task force press conference. He outlined his plans to slow immigration, including halting most green cards for 60 days. Read the full transcript here.']
# ['\xa0']
# []
# ['Transcribe Your Own Content']
# [' Try Rev for free', ' and save time transcribing. ', 'Transcribe', ' or ', 'caption', ' speeches, interviews, meetings, town halls, phone calls, and more. Rev is the largest, most trusted, fastest, and most accurate provider of ', 'transcription services', ' and ', 'closed captioning & subtitling services', ' in the world.']
# ...

# %% [markdown]
# ## For All Pages:

# %%
def run_bs4(link, lxml=None):
    user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.122 Safari/537.36'
    headers = {'User-Agent': user_agent}
    page = requests.get(link)
    html = page.content
    soup = bs4.BeautifulSoup(html, 'html.parser')
    return(soup)
